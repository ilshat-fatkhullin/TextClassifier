# %%
import pandas as pd

# %%
Sentences = pd.DataFrame.from_csv("../Data/sentences.csv")

# %%
Sentences.
# Out:
#                                                    Название произведения  \
# Предложение
# ﻿– Так ты приходи!                                              Гостинец
# – в третий раз попросил Сениста, и в третий раз...              Гостинец
# Еще бы не прийти, конечно прийду.                               Гостинец
# И снова они замолчали.                                          Гостинец
# Сениста лежал на спине, до подбородка укрытый с...              Гостинец
# Сазонке же хотелось уйти, но он не знал, как эт...              Гостинец
# Он бы еще посидел, если бы было о чем говорить;...              Гостинец
# Так, его все время тянуло называть Сенисту по и...              Гостинец
# И еще двух недель не прошло с тех пор, как он д...              Гостинец
# Сазонка решительно начал сползать со стула, но ...              Гостинец
# Болит, а?                                                       Гостинец
# Сениста утвердительно качнул головой и тихо отв...              Гостинец
# ...
